# %%
from project_detect import detect_multi

from pathlib import Path

# %%
root = Path('e:\\dev\\ai-code-doc-helper')

# %%
detect_multi(root=root)
# Out:
# MultiDetection(roots=[FolderDetection(path='e:\\dev\\ai-code-doc-helper', ecosystems=[EcosystemBlock(name='python', score=2.0, files=['pyproject.toml'], packages=[{'name': 'asttokens', 'version': '3.0.0'}, {'name': 'colorama', 'version': '0.4.6'}, {'name': 'comm', 'version': '0.2.3'}, {'name': 'debugpy', 'version': '1.8.17'}, {'name': 'decorator', 'version': '5.2.1'}, {'name': 'executing', 'version': '2.2.1'}, {'name': 'ipykernel', 'version': '7.1.0'}, {'name': 'ipython', 'version': '9.7.0'}, {'name': 'ipython_pygments_lexers', 'version': '1.1.1'}, {'name': 'jedi', 'version': '0.19.2'}, {'name': 'jupyter_client', 'version': '8.6.3'}, {'name': 'jupyter_core', 'version': '5.9.1'}, {'name': 'matplotlib-inline', 'version': '0.2.1'}, {'name': 'nest-asyncio', 'version': '1.6.0'}, {'name': 'parso', 'version': '0.8.5'}, {'name': 'platformdirs', 'version': '4.5.0'}, {'name': 'prompt_toolkit', 'version': '3.0.52'}, {'name': 'psutil', 'version': '7.1.3'}, {'name': 'pure_eval', 'version': '0.2.3
# ...
